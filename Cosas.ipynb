# %%
# Cosas


from re import A

from networkx import newman_watts_strogatz_graph


if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'RECEPCION'), 2, 
    if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'PISOS'), 1, 
        if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'SALA'), 3, 
            if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'SERVICIOS TECNICOS'), 4, 
                if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'COCINA'), 5, 
	                if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'ADMINISTRACION'), 6,
		                if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'SISTEMAS'), 7,
			                if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'RECURSOS HUMANOS'), 8,
				                if(equals(items('Aplicar_a_cada_uno_2')?['Departamento'], 'COMERCIAL'), 9, 0)))))))))




if(not(empty(variables('fecha_fin_1'))), variables('fecha_fin_1'), '"ESTE CONTRATO NO CONSTA DE FECHA FINAL"')

if(not(empty(triggerBody()['date_1'])), triggerBody()['date_1'], '"ESTE CONTRATO NO CONSTA DE FECHA FINAL"')


Boton Solicitud Permiso pone Solicitud Excedencia

- ControlDiarioBaja

- Quitar DataVerse del flujo de Altas

@{items('Aplicar_a_cada_uno')?['Correo']};@{variables('email_director')};@{variables('email_recepcion')}

Codigo QR y Tarjeta de Identificación


<div style="font-family: Arial, sans-serif; color: #333; padding: 20px; border: 1px solid #ddd; border-radius: 8px; line-height: 1.5;">
<h2 style="color: #0073e6; text-align: center;">🎉 ¡Bienvenido/a a Soho Boutique Hotels!</h2>
<p style="font-size: 16px;">
    Estimado/a <strong style="color: #0073e6;"> @{items('Aplicar_a_cada_uno')?['Primer_apellido']} @{items('Aplicar_a_cada_uno')?['Segundo_apellido']}, @{items('Aplicar_a_cada_uno')?['Nombre']}</strong>,
</p>

<p style="font-size: 16px;">
    Es un placer darte la bienvenida a <strong>Soho Boutique Hotels</strong>. Nos complace que te unas a nuestro equipo y estamos seguros de que tu incorporación será muy valiosa para nuestra empresa.
</p>

<div style="background: #f3faff; padding: 15px; border-left: 4px solid #0073e6; margin-top: 20px;">
    <p style="font-size: 16px; margin: 0;">
        <strong>📎 Documentación Adjunta:</strong>
    </p>
    <p style="font-size: 14px; margin: 5px 0 0 0;">
        Adjuntamos a este correo tu <strong>QR</strong> y tu <strong>tarjeta identificativa</strong>.
        Por favor, revisa los documentos y no dudes en contactarnos si tienes alguna pregunta o necesitas más información.
    </p>
</div>

<p style="font-size: 16px; margin-top: 20px;">
    Estamos emocionados de comenzar esta nueva etapa contigo y esperamos que te sientas parte de nuestra familia desde el primer día.
    Te deseamos mucho éxito en tu nuevo puesto y estamos aquí para apoyarte en todo lo que necesites.
</p>

<p style="font-size: 16px; margin-top: 20px;">
    <strong>📞 Contacto:</strong> No dudes en escribirnos si necesitas asistencia. ¡Estamos aquí para ayudarte!
</p>

<p style="font-size: 16px; margin-top: 20px;">
    <strong>Saludos cordiales,</strong> <br>
    <em>El equipo de Soho Boutique Hotels</em>
</p>
</div>
```

![image.png](attachment:c304c16d-1c83-40c9-be32-8877c3e774d6:image.png)

<!DOCTYPE html>
<html lang="es">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Permiso Aprobado</title>
<style>
body {
font-family: Arial, sans-serif;
background-color: #f4f4f4;
margin: 0;
padding: 20px;
}
.container {
background-color: #ffffff;
max-width: 600px;
margin: auto;
padding: 20px;
border-radius: 10px;
box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
}
h1 {
color: #2d89ef;
text-align: center;
}
p {
color: #333;
line-height: 1.6;
}
.highlight {
font-weight: bold;
color: #2d89ef;
}
.footer {
margin-top: 20px;
font-size: 0.9em;
color: #777;
text-align: center;
}
</style>
</head>
<body>

<div class="container">
<h1>Permiso</h1>
<p>Se ha concedido un permiso a <span class="highlight">@{triggerBody()['text_2']}</span> en

<span class="highlight">@{triggerBody()['text_1']}</span></p>
<p><strong>Motivos del permiso:</strong> @{triggerBody()['text_3']}</p>
<p><strong>Información adicional:</strong> @{triggerBody()['text_4']}</p>

<p><strong>Datos adjuntos:</strong> @{variables('vinculo_adjuntos')}</p>

</div>

</body>
</html>

[bahiamalaga@sohohoteles.com](mailto:bahiamalaga@sohohoteles.com)

[sbcolon@sohohoteles.com](mailto:sbcolon@sohohoteles.com)

[sburban@sohohoteles.com](mailto:sburban@sohohoteles.com)


**Orden variables PowerApps**
Excedencia.Run(
    Upper(Label14_55.Text); 
    varSociedad3; 
    Label14_54.Text; 
    TextInput1_6.Text; 

    If(
        IsBlank(TextInput1_8.Text);
        " ";
        TextInput1_8.Text
    );

    Text(DataCardValue27_11.SelectedDate; "yyyy-mm-dd"); 
    correoSesion;
    varCentro
);;



if(equals(variables('tipo jornada'), 'PARCIAL'), concat('PARCIAL - ', variables('horas_parcial'), ' horas'), variables('tipo jornada'))






@concat('https://make.powerautomate.com/environments/Default-a5839d11-3ae4-4e46-a6cb-db2abb961dfc/flows/32febbd9-118d-434c-997d-29289a1633d1/runs/', workflow()['run']['name'])






{
  "name": items('Apply_to_each_2')?['DisplayName'],
  "contentBytes": body('Get_attachment_content')?['$content'],
  "contentType": body('Get_attachment_content')?['$content-type']
}


{
  "name": items('Apply_to_each_2')?['DisplayName'],
  "contentBytes": body('Get_attachment_content')?['$content'],
  "contentType": body('Get_attachment_content')?['$content-type']
}

11912

NIF_NIE eq '@{triggerBody()['text']}' and Sociedad eq '@{triggerBody()['text_1']}'


if(equals(variables('tipo_jornada'), 'PARCIAL'), concat('PARCIAL - ', variables('horas_parcial'), ' horas'), variables('tipo_jornada'))


length(outputs('Obtener_elementos-Repos_Despidos')?['body/value'])


if(equals(items('Variables_Contrato')?['tipo_horas'], null), 0, items('Variables_Contrato')?['tipo_horas'])


if(equals(variables('tipo_jornada'), 'PARCIAL'), concat('PARCIAL - ', variables('horas_parcial'), ' - ', variables('tipo_horas'), variables('tipo_jornada')))


if(
  equals(variables('tipo_jornada'), 'PARCIAL'),
  concat('PARCIAL - ', variables('horas_parcial'), ' - ', variables('tipo_horas')),
  variables('tipo_jornada')
)


items('var_Contratos')?['Horario']
items('var_Contratos')?['tipo_horas']
items('var_Contratos')?['horas_contrato']
items('Variables_Contrato')?['tipo_horas']

json(concat('{',
'"name":"', items('Apply_to_each_2')?['DisplayName'], '",',
'"content":"', body('Get_attachment_content')?['$content'], '"',
'}'))


json(concat(
  '{',
  '"name":"', items('Apply_to_each_2')?['DisplayName'], '",',
  '"content":"', body('Get_attachment_content')?['$content'], '"',
  '}'
))
json(concat(
  '{',
  '"name":"', items('Apply_to_each_2')?['DisplayName'], '",',
  '"content":"', base64ToBinary(body('Get_attachment_content')?['$content']), '"',
  '}'
))


json(concat(
  '{',
  '"name":"', items('Apply_to_each_2')?['DisplayName'], '",',
  '"content":"', body('Get_attachment_content')?['$content'], '"',
  '}'
))


<p>Informamos que se ha realizado una modificación en la fecha final del contrato del empleado <strong>@{items('Aplicar_a_cada_uno_3')?['Nombre']} @{items('Aplicar_a_cada_uno_3')?['Primer_apellido']}</strong> con NIF/NIE <strong>@{triggerBody()['text']}</strong></p>

<p><strong>Datos del contrato:</strong></p>

<ul>
    <li><em>NIF/NIE:</em> @{triggerBody()['text']}</li>
    <li><em>Empleado:</em> @{items('Aplicar_a_cada_uno_3')?['Nombre']} @{items('Aplicar_a_cada_uno_3')?['Primer_apellido']}</li>
    <li><em>Contrato:</em> @{items('Aplicar_a_cada_uno_4')?['Tipo_Contrato/Value']}</li>
    <li><em>Fecha final de discontinuidad:</em> <strong>@{formatDateTime(variables('fecha_fin_nueva'), 'dd/MM/yyyy')}</strong> (<em>@{formatDateTime(items('Aplicar_a_cada_uno_4')?['Fecha_Fin'], 'dd/MM/yyyy')} anterior</em>)</li>
    <li><em>Departamento - Puesto:</em> @{items('Aplicar_a_cada_uno_4')?['Departamento']} - @{items('Aplicar_a_cada_uno_4')?['Puesto']}</li>
</ul>












@{variables('var_nombre')} @{variables('var_primer_apellido')} @{variables('var_segundo_apellido')},
Sociedad: @{triggerBody()['text_2']},
Con NIF/NIE @{triggerBody()['text']}.
Con IBAN @{variables('var_IBAN')}.
Con NAF @{variables('var_NAF')}.
Dirección de Notificaciones: @{variables('direccion_notificaciones')}.
Nacionalidad: @{variables('nacionalidad')}.
Teléfono: @{variables('telefono')}.
Fecha de Nacimiento: @{formatDateTime(variables('var_Fecha_nac'), 'dd/MM/yyyy')}.

Datos del contrato:
Sociedad: @{triggerBody()['text_2']},
Fecha de Inicio: @{formatDateTime(variables('varFechaInicio'), 'dd/MM/yyyy')}.
Tipo de Contrato: @{variables('var_tipo_contrato')},
Motivos del Contrato: @{variables('motivos_contrato')}
Departamento: @{variables('var_Departamento')},
Categoría: @{toUpper(variables('var_categoria'))},
Tipo de Horario: @{variables('var_tipo_horario')},
Horario: @{variables('horario')},
Horas: @{variables('horas_contrato')},
Tipo de horas: @{variables('tipo_horas')},
Fecha Final: @{if(not(empty(variables('varFecha_fin'))), formatDateTime(variables('varFecha_fin'), 'dd/MM/yyyy'), '"ESTE CONTRATO NO CONSTA DE FECHA FINAL"')
} ,
Salario: @{variables('var_salario')},
Salario Bruto: @{variables('var_sueldo')}.



if(
  empty(triggerBody()['text_2']),
  0,
  int(triggerBody()['text_2'])
)

if(
    empty(variables('horas_contrato')),
    0,
    variables('horas_contrato')
)

if(empty(items('variables_contratoo')?['horas_contrato']), 0, items('variables_contratoo')?['horas_contrato'])

split(triggerBody()['text'], '$')[0]


if(equals(items('variables_contratoo')?['horas_contrato'], null), 0, items('variables_contratoo')?['horas_contrato'])
   
   @{triggerBody()['text_14']}

if(equals(triggerBody()['text_14'], null), 0, triggerBody()['text_14'])

triggerBody()['text_15']

if(equals(triggerBody()['text_15'], null), 0, triggerBody()['text_15'])

formatDateTime(variables('fecha_fin_R') "yyyy-MM-dd")

triggerBody()['text_5']

if(equals(triggerBody()['text_5'], null), 0, triggerBody()['text_5'])

if(equals(triggerBody()['text_6'], null), 0, triggerBody()['text_6'])

if(equals(int(triggerBody()['text_7']), null), 0, triggerBody()['text_7'])

Tipo_Horario: if(empty(triggerBody()['text_8']), 0, triggerBody()['text_8'])

Horario: if(empty(triggerBody()['text_9']), 0, triggerBody()['text_9'])

Salario: if(empty(triggerBody()['text_10']), 0, triggerBody()['text_10'])

if(empty(variables('varSalarioBruto')), 0, variables('varSalarioBruto'))

Horas_Contrato: if(empty(triggerBody()['text_14']), 0, triggerBody()['text_14'])

Tipo_Horas: if(empty(triggerBody()['text_15']), 0, triggerBody()['text_15'])

Contrato Eventual: if(empty(triggerBody()['text_13']), 0, triggerBody()['text_13'])


lessOrEquals(
  div(
    sub(ticks(items('Aplicar_a_cada_uno')?['Fecha_Fin']), ticks(utcNow())),
    864000000000
  ),
  2
)




Empleados SB Málaga que estarán de vacaciones:

      76135728R        26/05-01/06
      50606706J        19/05-25/05    09/06-15/06
      25666896T        12/05-18/05    30/06-13/07
      77660180J        02/06-08/06    16/06-29/06
*/


Mañana añadir conector de correo en prod_word_modificaciones en el que se envie un correo antes de que llegue la aprobacion para avisar a rrhh que ha llegado la aprobación a asesoría

anacuetosalcedo@gmail.com


Flujos que utilizan el flujo de aprobacion de permisos:
- ALTA Bestia Negra 
- ALTA Cancelación Intento 
- Modificaciones 
- Llamamiento 
- Cancelación Pendiente 
- Cancelación Alta 

Añadir en el flujo de Llamamiento lo siguiente:

- tipo_horario
- horario
- horas_contrato
- tipo_horas


Para que SolicitarVacaciones no consuma tanto, podria hacer un flujo aparte que sea un control diario de vacaciones, quitar los actualizar del otro flujo y añadirlos en este, donde se actualice el estado en Principal por Vacaciones siempre y cuando la Fecha_Inicio sea igual a la del dia de la ejecucion del control.

A lo mejor también habria que hacer esto para el resto de flujos en los que haya fechas de contrato.


if(
  or(
    equals(triggerBody()['text_17'], ''),
    equals(triggerBody()['text_17'], null)
  ),
  0,
  formatDateTime(triggerBody()['text_17'], 'yyyy-MM-dd')
)

if(
  or(
    equals(variables('varFechaFin'), ''),
    equals(variables('varFechaFin'), null)
  ),
  0,
  formatDateTime(variables('varFechaFin'), 'yyyy-MM-dd')
)



variables('varSalarioBruto')

if(
  or(
    equals(variables('horario_repositorio'), null),
    equals(variables('horario_repositorio'), '')
  ),
  0,
  int(variables('horario_repositorio'))
)

items('variables_contratoo')?['tipo_horas']

if(
  or(
    equals(items('Variables_Repositorioo')?['horas_contrato'], null),
    equals(items('Variables_Repositorioo')?['horas_contrato'], '')
  ),
  0,
  int(items('Variables_Repositorioo')?['horas_contrato'])
)


<!DOCTYPE html>
<html>
  <body style="font-family: Arial, sans-serif; background-color: #f4f4f4; padding: 30px;">
    <div style="max-width: 650px; margin: auto; background-color: #ffffff; border-radius: 10px; padding: 25px; box-shadow: 0 2px 6px rgba(0,0,0,0.1);">
      
      <h2 style="color: #2c3e50; text-align: center;">📄 Petición de Modificación</h2>

      <p style="font-size: 16px; color: #333;">
        En <strong>Dalar Hoteles SL</strong> y <strong>SB Los Naranjos</strong>
      </p>

      <hr style="border: none; border-top: 1px solid #ddd; margin: 20px 0;">

      <h3 style="color: #2c3e50;">👤 Empleado</h3>
      <p style="font-size: 15px; color: #444;">
        <strong>Nombre:</strong> ABDELKRIM  EL ARRASSI, ISMAEL <br>
        <strong>NIF/NIE:</strong> 45315186B
      </p>

      <h3 style="color: #2c3e50;">⏰ Modificación realizada</h3>
      <p style="font-size: 15px; color: #444;">
        Se ha modificado el <strong>TIPO DE HORARIO</strong>.
      </p>

      <p style="font-size: 15px; color: #444; margin-top: 10px;">
        <strong>Anteriormente era:</strong><br>
        • Tipo de Horario: JORNADA COMPLETA<br>
        • Horario: 
      </p>

      <p style="font-size: 15px; color: #444;">
        <strong>Actualmente sería:</strong><br>
        • Tipo de Horario: TURNOS<br>
        • Horario: 7:00-13:00
      </p>

      <p style="font-size: 15px; color: #444; margin-top: 20px;">
        <strong>📅 Fecha de Efecto:</strong><br>
        2025-04-29
      </p>

      <p style="font-size: 13px; color: #888; text-align: center; margin-top: 30px;">
        Este mensaje ha sido generado automáticamente. Por favor, no responder a este correo.
      </p>

    </div>
  </body>
</html>





<!DOCTYPE html>
<html>
  <body style="font-family: Arial, sans-serif; background-color: #f4f4f4; padding: 30px;">
    <div style="max-width: 650px; margin: auto; background-color: #ffffff; border-radius: 10px; padding: 25px; box-shadow: 0 2px 6px rgba(0,0,0,0.1);">
      
      <h2 style="color: #2c3e50; text-align: center;">📄 Petición de Modificación</h2>

      <p style="font-size: 16px; color: #333;">
        En <strong>@{triggerOutputs()?['body/Sociedad']}</strong> y <strong>@{triggerOutputs()?['body/Centro']}</strong>
      </p>

      <hr style="border: none; border-top: 1px solid #ddd; margin: 20px 0;">

      <h3 style="color: #2c3e50;">👤 Empleado</h3>
      <p style="font-size: 15px; color: #444;">
        <strong>Nombre:</strong> @{variables('var_primer_apellido')} @{variables('var_segundo_apellido')}, @{variables('var_nombre')}<br>
        <strong>NIF/NIE:</strong> @{triggerOutputs()?['body/field_0']}
      </p>

      <h3 style="color: #2c3e50;">✏️ Modificación realizada</h3>
      <p style="font-size: 15px; color: #444;">
        Se ha modificado el <strong>@{variables('modif')}</strong>.
      </p>

<table style="width: 100%; border-collapse: collapse; font-family: Arial, sans-serif; font-size: 14px; margin-top: 20px; border: 1px solid #ccc;">
     @{variables('html')}
</table>

      <p style="font-size: 15px; color: #444; margin-top: 20px;">
        <strong>📅 Fecha de Efecto:</strong><br>
        @{variables('Fecha_Efecto')}
      </p>

      <p style="font-size: 13px; color: #888; text-align: center; margin-top: 30px;">
        Este mensaje ha sido generado automáticamente. Por favor, no responder a este correo.
      </p>

    </div>
  </body>
</html>
